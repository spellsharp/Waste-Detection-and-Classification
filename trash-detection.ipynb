# %%
# !pip install opencv-python
# !pip install ultralytics
# Out:
# Requirement already satisfied: opencv-python in /home/spellsharp/miniconda3/lib/python3.12/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: ultralytics in /home/spellsharp/miniconda3/lib/python3.12/site-packages (8.2.15)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torch>=1.8.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: six in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from cycler>=0.10->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/spellsharp/miniconda3/lib/python3.12/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
import os
os.environ["WANDB_MODE"] = "dryrun"

# %%
import cv2, os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
import time

# %%
class Classification:
    def __init__(self, model):
        self.model = model
    
    def draw_bbox(self, image, results):
        classes = results.names
        if isinstance(image, str):
            image = Image.open(image)
            image = np.array(image)

        for i in range(len(results.boxes)):
            box = results.boxes[i]
            tensor = box.xyxy[0]
            classname = classes[int(box.cls)]
            x1 = int(tensor[0].item())
            y1 = int(tensor[1].item())
            x2 = int(tensor[2].item())
            y2 = int(tensor[3].item())
            cv2.rectangle(image,(x1,y1),(x2,y2),(255,255,255),3)
            cv2.putText(image, classname, (int(x1) + 5, int(y1) + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255,255,255), 2)
        return image

    def predict_image(self, image):
        start_time =  time.time()
        results = self.model.predict(image)[0]
        end_time = time.time()
        inference_time = end_time - start_time
        
        image = self.draw_bbox(image, results)
        return image, inference_time
    
    def predict_multiple(self, path):
        output_imgs = []
        images = os.listdir(path)
        for image in images:
            image = 'images/' + image
            output_imgs.append(self.predict_image(image)[0])

        fig, axs = plt.subplots(len(output_imgs), 1, figsize=(16, 16))

        for i, img in enumerate(output_imgs):
            axs[i].imshow(img)
            axs[i].axis('off')
        plt.tight_layout()
        plt.show()

        fig.savefig('output.png')
    
    def predict_video(self, video_path, output_path, frames=None):
        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        total_inference_time = 0
        num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        try:
            while cap.isOpened():
                if frames is not None:
                    if cap.get(cv2.CAP_PROP_POS_FRAMES) >= frames:
                        break
                ret, frame = cap.read()
                if not ret:
                    break
                out_frame, inference_time = self.predict_image(out_frame)
                total_inference_time += inference_time
                out.write(out_frame)
        except Exception as e:
            print(f"An error occurred: {e}")
        finally:
            print(f"Total inference time: {total_inference_time} s")
            print("Total number of frames: ", num_frames)
            print(f"Average inference time per frame: {(total_inference_time * 1000) / num_frames} ms")

            cap.release()
            out.release()

    def process_stream(self, input_stream=0, rate=1):
        cap = cv2.VideoCapture(input_stream)
        try: 
            frame_count = 0
            total_inference_time = 0
            try:
                while(cap.isOpened()):
                
                    frame_count += 1
                    ret, frame = cap.read()
                    if ret:
                        copy_frame = np.copy(frame)
                        frame = cv2.resize(frame, (copy_frame.shape[1], copy_frame.shape[0]))
                        out_frame = cv2.resize(frame, (1000, 800))

                        if frame_count % rate == 0:
                            out_frame, inference_time = self.predict_image(out_frame)
                            total_inference_time += inference_time
                        cv2.imshow('Real Time Trash Detection', out_frame)
                        if cv2.waitKey(1) & 0xFF == ord('q'):
                            break
                    else:
                        break
            
            except Exception as e:
                print(f"An error occurred: {e}")
                cap.release()
                cv2.destroyAllWindows()

            print(f"Total inference time: {total_inference_time} s")
            print("Total number of frames: ", frame_count)
            print(f"Average inference time per frame: {(total_inference_time * 1000) / (1 if frame_count == 0 else frame_count)} ms")

            cap.release()
            cv2.destroyAllWindows()

        except KeyboardInterrupt:
            cap.release()
            cv2.destroyAllWindows()
            print("Stream stopped by user")

# %%
model = YOLO('best.pt')
path = 'images'
classification = Classification(model)

# %%
classification.process_stream()
# Out:
# 0: 512x640 (no detections), 158.1ms
# Speed: 2.6ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 133.5ms
# Speed: 2.8ms preprocess, 133.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 125.4ms
# Speed: 1.7ms preprocess, 125.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 130.3ms
# Speed: 2.8ms preprocess, 130.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 115.2ms
# Speed: 2.6ms preprocess, 115.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 117.0ms
# Speed: 1.9ms preprocess, 117.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 108.2ms
# Speed: 2.5ms preprocess, 108.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 110.7ms
# Speed: 2.5ms preprocess, 110.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 106.6ms
# Speed: 4.0ms preprocess, 106.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 161.2ms
# Speed: 6.5ms preprocess, 161.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 168.9ms
# Speed: 4.4ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 114.7ms
# Speed: 2.7ms preprocess, 114.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 146.5ms
# Speed: 2.5ms preprocess, 146.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 139.6ms
# Speed: 2.3ms preprocess, 139.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 121.0ms
# Speed: 2.4ms preprocess, 121.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 124.9ms
# Speed: 4.3ms preprocess, 124.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 108.2ms
# Speed: 2.5ms preprocess, 108.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 116.1ms
# Speed: 2.6ms preprocess, 116.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 127.8ms
# Speed: 2.5ms preprocess, 127.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 138.1ms
# Speed: 2.8ms preprocess, 138.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 119.7ms
# Speed: 2.3ms preprocess, 119.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 120.1ms
# Speed: 5.4ms preprocess, 120.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 123.2ms
# Speed: 15.0ms preprocess, 123.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 124.5ms
# Speed: 2.6ms preprocess, 124.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 134.9ms
# Speed: 2.4ms preprocess, 134.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 119.8ms
# Speed: 2.9ms preprocess, 119.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 130.5ms
# Speed: 2.3ms preprocess, 130.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 128.6ms
# Speed: 2.8ms preprocess, 128.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 122.8ms
# Speed: 1.7ms preprocess, 122.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 118.4ms
# Speed: 1.7ms preprocess, 118.4ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 114.0ms
# Speed: 2.8ms preprocess, 114.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 115.6ms
# Speed: 2.4ms preprocess, 115.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 118.8ms
# Speed: 4.0ms preprocess, 118.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 177.6ms
# Speed: 3.0ms preprocess, 177.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 117.6ms
# Speed: 2.8ms preprocess, 117.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 106.7ms
# Speed: 8.8ms preprocess, 106.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 118.0ms
# Speed: 2.7ms preprocess, 118.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 110.6ms
# Speed: 2.9ms preprocess, 110.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# Stream stopped by user
